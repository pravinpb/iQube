# %%
import seaborn as sns
# %matplotlib inline

# %%
data = sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(data['tip'])
# Out:
# c:\Users\Pravin P B\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(data['tip'],kde = False,bins = 15)
# Out:
# c:\Users\Pravin P B\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %%
sns.jointplot(x = 'total_bill',y = 'size', data = data,kind = 'reg')

# %%
sns.jointplot(x = 'total_bill',y = 'tip', data = data,kind = 'hex')

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue = 'smoker')

# %%
sns.rugplot(data['tip'])
sns.kdeplot(data['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# MOdule 2 Catagorical plot

# %%
sns.barplot(x='smoker',y = 'total_bill',data = data)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.countplot(x = 'smoker',data = data)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.boxplot(x = 'day',y = 'tip',data = data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(y = 'day',x = 'tip',data = data,orient='h')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.boxplot(y = 'day',x = 'tip',data = data,orient='h',hue='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x="smoker", y="total_bill", data=data,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.violinplot(x="smoker", y="total_bill", data=data,palette='rainbow',hue = 'sex')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.violinplot(x="smoker", y="total_bill", data=data,palette='rainbow',hue = 'sex',split=True)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=data,jitter=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=data,jitter=False,hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Module 3 MAtrix PLot

# %%
flight = sns.load_dataset('flights')

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data.corr(),annot=True,cmap='Pastel1')
# Out:
# <AxesSubplot:>

# %%
x = flight.pivot_table(values='passengers',index='month',columns='year')
x
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(x,annot=True,linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# Module 4
